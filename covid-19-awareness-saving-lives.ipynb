# %% [markdown]
# ![](https://media.giphy.com/media/IbmS6XKR5fTVchlxcN/giphy.gif)

# %% [markdown]
# **CORONAVIRUS HAS CLAIMED PRECIOUS LIVES THOUGHOUT THE WORLD. PEOPLE ACROSS THE GLOBE ARE DOING COUNTLESS HOURS OF RESEARCH TO FIND A SOLUTION. MY WORK MEASURES THE AMOUNT OF WORKS DONE BY TITLES PUBLISHED IN JOURNALS ACROSS THE GLOBE AND COMPARES EACH JOURNAL WITH THE AMOUNTS OF TITLES PASSAGES THEY HAVE PRODUCED ON THE CORONA VIRUS WHICH MIGHT BE CLEAR MEASURE OF THERE PARTICIPATION IN CREATING AWARENESS AND DISPLAY OF THE SPIRIT OF JOUNALISM. I AM USING WHO DATA AND MY OWN CREATED DATASET TO DERIVE THE RESULTS **

# %% [markdown]
# <img src="https://www.elsevier.com/__data/assets/image/0012/974739/coronavirus-image-iStock-628925532-full-width-wide.jpg">

# %% [markdown]
# image credits = elsevierdotcom

# %% [markdown]
# ![](https://mail.google.com/mail/u/0?ui=2&ik=17b7366792&attid=0.1&permmsgid=msg-a:r7913645352209974806&th=1725c00afb07d2c0&view=fimg&sz=s0-l75-ft&attbid=ANGjdJ-TKYiM5aCjBsbcntfqIzHDmQd5dgmIF1ysUBmVw71AW20NXX-NvgxvMIfpvn1qj_HpyaTQaGERB6xG75gymW1tMoRTvdZ8OeJWX8E5yWCsKyJe8o-9abrODEo&disp=emb&realattid=ii_kaqynnzc0)

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as aware

# %%
df = pd.read_csv("../input/who-data-base-for-public-use/2020-Full database.csv")['Journal']

# %% [markdown]
# Lets consider those Journals Who have published atleast 50 or more titles on Covid-19 till now according to WHO data. I am taking the first 37 values as beyond that no Journal has produced atleast 50 or more titles. We may also have to check data for the same jounal with different names repeated more than once.

# %%
dg = df.value_counts()

journal = dg.head(37)

# %%
journal
# Out:
# BMJ                                               404
# Nature                                            267
# The Lancet                                        226
# Science                                           199
# Journal of medical virology                       190
# Journal of Infection                              146
# The Lancet Infectious Diseases                    128
# JAMA                                              128
# International Journal of Infectious Diseases      104
# New Scientist                                     101
# New England Journal of Medicine                   100
# Journal of Medical Virology                       100
# Clinical Infectious Diseases                       97
# Journal of the American Academy of Dermatology     95
# Infection Control & Hospital Epidemiology          92
# Travel Medicine and Infectious Disease             83
# Revue medicale suisse                              81
# BMJ (Clinical research ed.)                        81
# C&EN Global Enterprise                             79
# Science of The Total Environment                   72
# Psychiatry Research                                71
# The Lancet Respiratory Medicine                    71
# Medical Hypotheses                                 69
# The New England journal of medicine                67
# Asian Journal of Psychiatry                        63
# Brain, Behavior, and Immunity                      61
# Head & neck                                        61
# Journal of the American Geriatrics Society         60
# Journal of Clinical Virology                       58
# Gastroenterology                                   58
# Eurosurveillance                                   57
# European Heart Journal                             57
# Radiology                                          57
# Anaesthesia                                        54
# Critical Care                                      53
# Journal of Hospital Infection                      53
# Anesth Analg                                       50
# Name: Journal, dtype: int64

# %%
word = ','.join(map(str, journal)) #I am joining the number to form a series to put in a dataframe

# %%
word
# Out:
# '404,267,226,199,190,146,128,128,104,101,100,100,97,95,92,83,81,81,79,72,71,71,69,67,63,61,61,60,58,58,57,57,57,54,53,53,50'

# %% [markdown]
# Below is our Dataframe named Awareness_creators and has names of journals who have produced atleast 50 or more titles on covid-19

# %%
Awareness_creators={'Journals':['BMJ',                                               
'Nature',                                            
'The Lancet',                                        
'Science',                                           
'Journal of medical virology',                       
'Journal of Infection',                              
'The Lancet Infectious Diseases',                    
'JAMA',                                              
'International Journal of Infectious Diseases',      
'New Scientist',                                     
'New England Journal of Medicine',                   
                       
'Clinical Infectious Diseases',                       
'Journal of the American Academy of Dermatology',     
'Infection Control & Hospital Epidemiology',          
'Travel Medicine and Infectious Disease',             
                                
'Revue medicale suisse',                              
'C&EN Global Enterprise',                             
'Science of The Total Environment',                   
'The Lancet Respiratory Medicine',                    
'Psychiatry Research',                                
'Medical Hypotheses',                                
               
'Asian Journal of Psychiatry',                        
'Head & neck',                                        
'Brain, Behavior, and Immunity',                      
'Journal of the American Geriatrics Society',         
'Journal of Clinical Virology',                       
'Gastroenterology',                                   
'European Heart Journal',                             
'Eurosurveillance',                                  
'Radiology',                                          
'Anaesthesia',                                        
'Journal of Hospital Infection',                      
'Critical Care',                                      
'Anesth Analg'],'Number_of_titles_produced':[485,267,226,199,290,146,128,128,104,101,167,97,95,92,83,81,79,72,71,71,69,63,61,61,60,58,58,57,57,57,54,53,53,50]}

Awareness_creators=pd.DataFrame(data=Awareness_creators,index=range(34))
Awareness_creators.style.background_gradient(cmap='plasma')
# Out:
# <style  type="text/css" >
#     #T_67caf0c8_a10e_11ea_b21b_0242ac130202row0_col1 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row1_col1 {
#             background-color:  #cb4679;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row2_col1 {
#             background-color:  #b22b8f;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row3_col1 {
#             background-color:  #9e199d;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row4_col1 {
#             background-color:  #d7566c;
#             color:  #000000;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row5_col1 {
#             background-color:  #7201a8;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row6_col1 {
#             background-color:  #6100a7;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row7_col1 {
#             background-color:  #6100a7;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row8_col1 {
#             background-color:  #4b03a1;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row9_col1 {
#             background-color:  #4903a0;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row10_col1 {
#             background-color:  #8405a7;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row11_col1 {
#             background-color:  #44039e;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row12_col1 {
#             background-color:  #43039e;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row13_col1 {
#             background-color:  #3f049c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row14_col1 {
#             background-color:  #370499;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row15_col1 {
#             background-color:  #350498;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row16_col1 {
#             background-color:  #330597;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row17_col1 {
#             background-color:  #2a0593;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row18_col1 {
#             background-color:  #2a0593;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row19_col1 {
#             background-color:  #2a0593;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row20_col1 {
#             background-color:  #280592;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row21_col1 {
#             background-color:  #20068f;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row22_col1 {
#             background-color:  #1d068e;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row23_col1 {
#             background-color:  #1d068e;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row24_col1 {
#             background-color:  #1b068d;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row25_col1 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row26_col1 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row27_col1 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row28_col1 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row29_col1 {
#             background-color:  #19068c;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row30_col1 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row31_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row32_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_67caf0c8_a10e_11ea_b21b_0242ac130202row33_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }</style><table id="T_67caf0c8_a10e_11ea_b21b_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Journals</th>        <th class="col_heading level0 col1" >Number_of_titles_produced</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row0_col0" class="data row0 col0" >BMJ</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row0_col1" class="data row0 col1" >485</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row1_col0" class="data row1 col0" >Nature</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row1_col1" class="data row1 col1" >267</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row2_col0" class="data row2 col0" >The Lancet</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row2_col1" class="data row2 col1" >226</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row3_col0" class="data row3 col0" >Science</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row3_col1" class="data row3 col1" >199</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row4_col0" class="data row4 col0" >Journal of medical virology</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row4_col1" class="data row4 col1" >290</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row5_col0" class="data row5 col0" >Journal of Infection</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row5_col1" class="data row5 col1" >146</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row6_col0" class="data row6 col0" >The Lancet Infectious Diseases</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row6_col1" class="data row6 col1" >128</td>
#             </tr>
#             <tr>
#                         <th id="T_67caf0c8_a10e_11ea_b21b_0242ac130202level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row7_col0" class="data row7 col0" >JAMA</td>
#                         <td id="T_67caf0c8_a10e_11ea_b21b_0242ac130202row7_col1" class="data row7 col1" >128</td>

# %% [markdown]
# lets visualize this data frame with a Bar Chart!!

# %%
fig = aware.bar(Awareness_creators[['Journals', 'Number_of_titles_produced']].sort_values('Number_of_titles_produced', ascending=False), 
             y="Number_of_titles_produced", x="Journals", color='Journals',  width=1500, height=700,
             log_y=True, template='ggplot2', title='AWARENESS SAVING LIVES')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="09b77731-ca1c-4c30-9b19-5ed7357b8146" class="plotly-graph-div" style="height:700px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09b77731-ca1c-4c30-9b19-5ed7357b8146")) {
#                     Plotly.newPlot(
#                         '09b77731-ca1c-4c30-9b19-5ed7357b8146',
#                         [{"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "BMJ", "marker": {"color": "#F8766D"}, "name": "BMJ", "offsetgroup": "BMJ", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["BMJ"], "xaxis": "x", "y": [485], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "Journal of medical virology", "marker": {"color": "#A3A500"}, "name": "Journal of medical virology", "offsetgroup": "Journal of medical virology", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Journal of medical virology"], "xaxis": "x", "y": [290], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "Nature", "marker": {"color": "#00BF7D"}, "name": "Nature", "offsetgroup": "Nature", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nature"], "xaxis": "x", "y": [267], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "The Lancet", "marker": {"color": "#00B0F6"}, "name": "The Lancet", "offsetgroup": "The Lancet", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["The Lancet"], "xaxis": "x", "y": [226], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "Science", "marker": {"color": "#E76BF3"}, "name": "Science", "offsetgroup": "Science", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Science"], "xaxis": "x", "y": [199], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "New England Journal of Medicine", "marker": {"color": "#F8766D"}, "name": "New England Journal of Medicine", "offsetgroup": "New England Journal of Medicine", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["New England Journal of Medicine"], "xaxis": "x", "y": [167], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "Journal of Infection", "marker": {"color": "#A3A500"}, "name": "Journal of Infection", "offsetgroup": "Journal of Infection", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Journal of Infection"], "xaxis": "x", "y": [146], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "The Lancet Infectious Diseases", "marker": {"color": "#00BF7D"}, "name": "The Lancet Infectious Diseases", "offsetgroup": "The Lancet Infectious Diseases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["The Lancet Infectious Diseases"], "xaxis": "x", "y": [128], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "JAMA", "marker": {"color": "#00B0F6"}, "name": "JAMA", "offsetgroup": "JAMA", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["JAMA"], "xaxis": "x", "y": [128], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_titles_produced=%{y}<extra></extra>", "legendgroup": "International Journal of Infectious Diseases", "marker": {"color": "#E76BF3"}, "name": "International Journal of Infectious Diseases", "offsetgroup": "International Journal of Infectious Diseases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Journal of Infectious Diseases"], "xaxis": "x", "y": [104], "yaxis": "y"}, {"alignmentgroup" ...

# %%
word = ','.join(map(str, df)) # Now we join the words in the Journal column of the who dataset to make a WordCloud visualize

# %%
from wordcloud import WordCloud , STOPWORDS #Stopwords to remove unecessary words

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = "White", max_words = 200, stopwords = stopwords).generate(word)

# %%
plt.figure(1,figsize=(20, 20))
plt.axis('off')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()

# %% [markdown]
# ![](https://mail.google.com/mail/u/0?ui=2&ik=17b7366792&attid=0.1&permmsgid=msg-a:r-7286449435814262293&th=17254dee9cd7195e&view=fimg&sz=s0-l75-ft&attbid=ANGjdJ8AWBE31FEtADkOWpnrZxwIZ6DaNiDj1jMDxNT4zED3n0TBWGk4qzDOPXUGPR5UD_N3VmhBaObSSaf5ZCacbVZPiZAXlriQcK2xWCbzTgqEnszG6oOILU63f0c&disp=emb&realattid=ii_kaozf4dk0)

# %% [markdown]
# ![](https://mail.google.com/mail/u/0?ui=2&ik=17b7366792&attid=0.1&permmsgid=msg-a:r6387276066474129052&th=17254e2351d5a047&view=fimg&sz=s0-l75-ft&attbid=ANGjdJ9C4bkskQAuwn4IaWTybPCzxC03XCsiEBSEinFy1sfruftTAHvolRBeOhdfKnEnK7deJFiKzJlnZlH9wzzeeYYIkvh9oLdSpeCOFRGCVbrNXas0j17jKGGSORU&disp=emb&realattid=ii_kaozjssn0)

# %% [markdown]
# Below is a Pie chart of the title percentage of each selected Journal which shows there contribution to the whole.

# %%
fig = aware.pie(Awareness_creators,
             values="Number_of_titles_produced",
             names="Journals",
             template="seaborn")
fig.update_traces(rotation=90, pull=0.05, textinfo="percent+label")
fig.show()
# Out:
# <div>
#
#
#             <div id="4bec8a85-2640-4000-860f-0255d36cf0e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4bec8a85-2640-4000-860f-0255d36cf0e9")) {
#                     Plotly.newPlot(
#                         '4bec8a85-2640-4000-860f-0255d36cf0e9',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Journals=%{label}<br>Number_of_titles_produced=%{value}<extra></extra>", "labels": ["BMJ", "Nature", "The Lancet", "Science", "Journal of medical virology", "Journal of Infection", "The Lancet Infectious Diseases", "JAMA", "International Journal of Infectious Diseases", "New Scientist", "New England Journal of Medicine", "Clinical Infectious Diseases", "Journal of the American Academy of Dermatology", "Infection Control & Hospital Epidemiology", "Travel Medicine and Infectious Disease", "Revue medicale suisse", "C&EN Global Enterprise", "Science of The Total Environment", "The Lancet Respiratory Medicine", "Psychiatry Research", "Medical Hypotheses", "Asian Journal of Psychiatry", "Head & neck", "Brain, Behavior, and Immunity", "Journal of the American Geriatrics Society", "Journal of Clinical Virology", "Gastroenterology", "European Heart Journal", "Eurosurveillance", "Radiology", "Anaesthesia", "Journal of Hospital Infection", "Critical Care", "Anesth Analg"], "legendgroup": "", "name": "", "pull": 0.05, "rotation": 90, "showlegend": true, "textinfo": "percent+label", "type": "pie", "values": [485, 267, 226, 199, 290, 146, 128, 128, 104, 101, 167, 97, 95, 92, 83, 81, 79, 72, 71, 71, 69, 63, 61, 61, 60, 58, 58, 57, 57, 57, 54, 53, 53, 50]}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30 ...

# %% [markdown]
# **BELOW IS A DONUT GRAPH OF THE SAME**

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(25,25))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Awareness_creators['Number_of_titles_produced'], labels=Awareness_creators.Journals, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Journals by titles produced')
plt.show()

# %% [markdown]
# **Now we read the Awareness Dataset I made which contains the estimated readership of these Jounals. This is the first dataset that I have created, and I have made it public so you can alo use it for understanding how awareness of this apidemic is saving lives**

# %%
df1 = pd.read_csv("../input/covid19-awareness-dataset/AWARENESS DATASET.csv")

# %%
df1=pd.DataFrame(data=df1,index=range(33))
df1
# Out:
#                                              Journals Number_of_Readers
# 0   BMJ                                           ...          50000000
# 1   Nature                                        ...          4,00,000
# 2   The Lancet                                    ...          10159512
# 3   Science                                       ...          5,70,400
# 4   Journal of medical virology                   ...         2,90,796‬
# 5   Journal of Infection                          ...         1,76,796‬
# 6   The Lancet Infectious Diseases                ...        10,19,388‬
# 7   JAMA                                          ...          20000000
# 8   International Journal of Infectious Diseases  ...          3,62,148
# 9   New Scientist                                 ...           1000000
# 10  New England Journal of Medicine               ...          6,00,000
# 11  Clinical Infectious Diseases                  ...          1,79,928
# 12  Journal of the American Academy of Dermatology...        19,42,080‬
# 13  Infection Control & Hospital Epidemiology     ...         4,96,176‬
# 14  Travel Medicine and Infectious Disease        ...           3000000
# 15  Revue medicale suisse                         ...          3,30,252
# 16  C&EN Global Enterprise                        ...         3,11,172‬
# 17  Science of The Total Environment              ...           286674
# 18  Psychiatry Research                           ...         2,65,268‬
# 19  Medical Hypotheses                            ...         29,06,226
# 20  Asian Journal of Psychiatry                   ...           2000000
# 21  Head & neck                                   ...          5,00,000
# 22  Brain, Behavior, and Immunity                 ...         1,50,144‬
# 23  Journal of the American Geriatrics Society    ...         3,20,172‬
# 24  Journal of Clinical Virology                  ...           11,844‬
# 25  Gastroenterology                              ...             30000
# 26  European Heart Journal                        ...         3,59,256‬
# 27  Eurosurveillance                              ...         28,00,000
# 28  Radiology                                     ...            54,000
# 29  Anaesthesia                                   ...           2400000
# 30  Journal of Hospital Infection                 ...         2,72,268‬
# 31  Critical Care                                 ...          3,00,068
# 32  Anesth Analg                                  ...          1,17,120

# %% [markdown]
# **Lets make a DataFrame to experiment with our new Dataset **

# %%
PEOPLE_AWARE={'Journals':['BMJ',                                               
'Nature',                                            
'The Lancet',                                        
'Science',                                           
'Journal of medical virology',                       
'Journal of Infection',                              
'The Lancet Infectious Diseases',                    
'JAMA',                                              
'International Journal of Infectious Diseases',      
'New Scientist',                                     
'New England Journal of Medicine',                   
                       
'Clinical Infectious Diseases',                       
'Journal of the American Academy of Dermatology',     
'Infection Control & Hospital Epidemiology',          
'Travel Medicine and Infectious Disease',             
                                
'Revue medicale suisse',                              
'C&EN Global Enterprise',                             
'Science of The Total Environment',                   
                    
'Psychiatry Research',                                
'Medical Hypotheses',                                
               
'Asian Journal of Psychiatry',                        
'Head & neck',                                        
'Brain, Behavior, and Immunity',                      
'Journal of the American Geriatrics Society',         
'Journal of Clinical Virology',                       
'Gastroenterology',                                   
'European Heart Journal',                             
'Eurosurveillance',                                  
'Radiology',                                          
'Anaesthesia',                                        
'Journal of Hospital Infection',                      
'Critical Care',                                      
'Anesth Analg'],'Number_of_Readers':[50000000,400000,10159512,570400,290796,176796,1019388,20000000,362148,1000000,600000,179928,1942080,496176,3000000,330252,311172,286674,265268,2906226,2000000,500000,150144,320172,11844,30000,359256,2800000,54000,2400000,272268,300068,117120]}

PEOPLE_AWARE=pd.DataFrame(data=PEOPLE_AWARE,index=range(33))
PEOPLE_AWARE.style.background_gradient(cmap='plasma')
# Out:
# <style  type="text/css" >
#     #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row0_col1 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row1_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row2_col1 {
#             background-color:  #6a00a8;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row3_col1 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row4_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row5_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row6_col1 {
#             background-color:  #1b068d;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row7_col1 {
#             background-color:  #b12a90;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row8_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row9_col1 {
#             background-color:  #1b068d;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row10_col1 {
#             background-color:  #16078a;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row11_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row12_col1 {
#             background-color:  #240691;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row13_col1 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row14_col1 {
#             background-color:  #2f0596;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row15_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row16_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row17_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row18_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row19_col1 {
#             background-color:  #2e0595;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row20_col1 {
#             background-color:  #260591;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row21_col1 {
#             background-color:  #130789;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row22_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row23_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row24_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row25_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row26_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row27_col1 {
#             background-color:  #2e0595;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row28_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row29_col1 {
#             background-color:  #2a0593;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row30_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row31_col1 {
#             background-color:  #100788;
#             color:  #f1f1f1;
#         }    #T_6a2faf2a_a10e_11ea_b21b_0242ac130202row32_col1 {
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }</style><table id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Journals</th>        <th class="col_heading level0 col1" >Number_of_Readers</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row0_col0" class="data row0 col0" >BMJ</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row0_col1" class="data row0 col1" >50000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row1_col0" class="data row1 col0" >Nature</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row1_col1" class="data row1 col1" >400000</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row2_col0" class="data row2 col0" >The Lancet</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row2_col1" class="data row2 col1" >10159512</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row3_col0" class="data row3 col0" >Science</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row3_col1" class="data row3 col1" >570400</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row4_col0" class="data row4 col0" >Journal of medical virology</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row4_col1" class="data row4 col1" >290796</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row5_col0" class="data row5 col0" >Journal of Infection</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row5_col1" class="data row5 col1" >176796</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row6_col0" class="data row6 col0" >The Lancet Infectious Diseases</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row6_col1" class="data row6 col1" >1019388</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row7_col0" class="data row7 col0" >JAMA</td>
#                         <td id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202row7_col1" class="data row7 col1" >20000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6a2faf2a_a10e_11ea_b21b_0242ac130202level

# %% [markdown]
# **LETS MAKE A PIE CHART TO SEE THE PERCENTAGE OF READERS TOTAL POPULATION COVERED BY EACH JOURNAL**

# %%
fig = aware.pie(PEOPLE_AWARE, width=1200, height=1200,
             values="Number_of_Readers",
             names="Journals",
             template="seaborn")
fig.update_traces(rotation=90, pull=0.05, textinfo="percent+label")
fig.show()
# Out:
# <div>
#
#
#             <div id="a8ac0b61-3e51-4527-9dec-cdabbb37c1bc" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8ac0b61-3e51-4527-9dec-cdabbb37c1bc")) {
#                     Plotly.newPlot(
#                         'a8ac0b61-3e51-4527-9dec-cdabbb37c1bc',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Journals=%{label}<br>Number_of_Readers=%{value}<extra></extra>", "labels": ["BMJ", "Nature", "The Lancet", "Science", "Journal of medical virology", "Journal of Infection", "The Lancet Infectious Diseases", "JAMA", "International Journal of Infectious Diseases", "New Scientist", "New England Journal of Medicine", "Clinical Infectious Diseases", "Journal of the American Academy of Dermatology", "Infection Control & Hospital Epidemiology", "Travel Medicine and Infectious Disease", "Revue medicale suisse", "C&EN Global Enterprise", "Science of The Total Environment", "Psychiatry Research", "Medical Hypotheses", "Asian Journal of Psychiatry", "Head & neck", "Brain, Behavior, and Immunity", "Journal of the American Geriatrics Society", "Journal of Clinical Virology", "Gastroenterology", "European Heart Journal", "Eurosurveillance", "Radiology", "Anaesthesia", "Journal of Hospital Infection", "Critical Care", "Anesth Analg"], "legendgroup": "", "name": "", "pull": 0.05, "rotation": 90, "showlegend": true, "textinfo": "percent+label", "type": "pie", "values": [50000000, 400000, 10159512, 570400, 290796, 176796, 1019388, 20000000, 362148, 1000000, 600000, 179928, 1942080, 496176, 3000000, 330252, 311172, 286674, 265268, 2906226, 2000000, 500000, 150144, 320172, 11844, 30000, 359256, 2800000, 54000, 2400000, 272268, 300068, 117120]}],
#                         {"height": 1200, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960 ...

# %% [markdown]
# **LETS MAKE A BAR CHART TO VISUALIZE THE READERS AND SEE WHO COVERED THE MOST AND WHO COVERED THE LEAST NUMBER OF READERS FROM THE READERS POPULATION**

# %%
fig = aware.bar(PEOPLE_AWARE[['Journals', 'Number_of_Readers']].sort_values('Number_of_Readers', ascending=False), 
             y="Number_of_Readers", x="Journals", color='Journals', width=1500, height=700,
             log_y=True, template='ggplot2', title='READERS WHO READ ABOUT COVID-19 AND MAY TAKE PRECAUTION = SAVING LIVES')
fig.show()
# Out:
# <div>
#
#
#             <div id="85ba621a-4761-477a-ab9f-76a402d91e90" class="plotly-graph-div" style="height:700px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85ba621a-4761-477a-ab9f-76a402d91e90")) {
#                     Plotly.newPlot(
#                         '85ba621a-4761-477a-ab9f-76a402d91e90',
#                         [{"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "BMJ", "marker": {"color": "#F8766D"}, "name": "BMJ", "offsetgroup": "BMJ", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["BMJ"], "xaxis": "x", "y": [50000000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "JAMA", "marker": {"color": "#A3A500"}, "name": "JAMA", "offsetgroup": "JAMA", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["JAMA"], "xaxis": "x", "y": [20000000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "The Lancet", "marker": {"color": "#00BF7D"}, "name": "The Lancet", "offsetgroup": "The Lancet", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["The Lancet"], "xaxis": "x", "y": [10159512], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Travel Medicine and Infectious Disease", "marker": {"color": "#00B0F6"}, "name": "Travel Medicine and Infectious Disease", "offsetgroup": "Travel Medicine and Infectious Disease", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Travel Medicine and Infectious Disease"], "xaxis": "x", "y": [3000000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Medical Hypotheses", "marker": {"color": "#E76BF3"}, "name": "Medical Hypotheses", "offsetgroup": "Medical Hypotheses", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Medical Hypotheses"], "xaxis": "x", "y": [2906226], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Eurosurveillance", "marker": {"color": "#F8766D"}, "name": "Eurosurveillance", "offsetgroup": "Eurosurveillance", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Eurosurveillance"], "xaxis": "x", "y": [2800000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Anaesthesia", "marker": {"color": "#A3A500"}, "name": "Anaesthesia", "offsetgroup": "Anaesthesia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Anaesthesia"], "xaxis": "x", "y": [2400000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Asian Journal of Psychiatry", "marker": {"color": "#00BF7D"}, "name": "Asian Journal of Psychiatry", "offsetgroup": "Asian Journal of Psychiatry", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Asian Journal of Psychiatry"], "xaxis": "x", "y": [2000000], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "Journal of the American Academy of Dermatology", "marker": {"color": "#00B0F6"}, "name": "Journal of the American Academy of Dermatology", "offsetgroup": "Journal of the American Academy of Dermatology", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Journal of the American Academy of Dermatology"], "xaxis": "x", "y": [1942080], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{x}<br>Number_of_Readers=%{y}<extra></extra>", "legendgroup": "The Lancet Infectious Diseases", "marker": {"color": "#E76BF3"}, "name": "The Lancet Infectious Diseases", "offsetgroup": "The Lancet Infectious Diseases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["The Lancet Infectious Diseases"], "xaxis": "x", " ...

# %%
fig = aware.bar(PEOPLE_AWARE[['Journals', 'Number_of_Readers']].sort_values('Number_of_Readers', ascending=False), 
             y="Journals", x="Number_of_Readers", color='Journals',orientation = 'h',width=1500, height=1000,
             log_x=True, template='ggplot2', title='READERS WHO READ ABOUT COVID-19 AND MAY TAKE PRECAUTION = SAVING LIVES')
fig.show()
# Out:
# <div>
#
#
#             <div id="98264a83-210e-4e45-b23a-3de2a4d3c253" class="plotly-graph-div" style="height:1000px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("98264a83-210e-4e45-b23a-3de2a4d3c253")) {
#                     Plotly.newPlot(
#                         '98264a83-210e-4e45-b23a-3de2a4d3c253',
#                         [{"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "BMJ", "marker": {"color": "#F8766D"}, "name": "BMJ", "offsetgroup": "BMJ", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [50000000], "xaxis": "x", "y": ["BMJ"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "JAMA", "marker": {"color": "#A3A500"}, "name": "JAMA", "offsetgroup": "JAMA", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [20000000], "xaxis": "x", "y": ["JAMA"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "The Lancet", "marker": {"color": "#00BF7D"}, "name": "The Lancet", "offsetgroup": "The Lancet", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [10159512], "xaxis": "x", "y": ["The Lancet"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Travel Medicine and Infectious Disease", "marker": {"color": "#00B0F6"}, "name": "Travel Medicine and Infectious Disease", "offsetgroup": "Travel Medicine and Infectious Disease", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3000000], "xaxis": "x", "y": ["Travel Medicine and Infectious Disease"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Medical Hypotheses", "marker": {"color": "#E76BF3"}, "name": "Medical Hypotheses", "offsetgroup": "Medical Hypotheses", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2906226], "xaxis": "x", "y": ["Medical Hypotheses"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Eurosurveillance", "marker": {"color": "#F8766D"}, "name": "Eurosurveillance", "offsetgroup": "Eurosurveillance", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2800000], "xaxis": "x", "y": ["Eurosurveillance"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Anaesthesia", "marker": {"color": "#A3A500"}, "name": "Anaesthesia", "offsetgroup": "Anaesthesia", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2400000], "xaxis": "x", "y": ["Anaesthesia"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Asian Journal of Psychiatry", "marker": {"color": "#00BF7D"}, "name": "Asian Journal of Psychiatry", "offsetgroup": "Asian Journal of Psychiatry", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000000], "xaxis": "x", "y": ["Asian Journal of Psychiatry"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "Journal of the American Academy of Dermatology", "marker": {"color": "#00B0F6"}, "name": "Journal of the American Academy of Dermatology", "offsetgroup": "Journal of the American Academy of Dermatology", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1942080], "xaxis": "x", "y": ["Journal of the American Academy of Dermatology"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Journals=%{y}<br>Number_of_Readers=%{x}<extra></extra>", "legendgroup": "The Lancet Infectious Diseases", "marker": {"color": "#E76BF3"}, "name": "The Lancet Infectious Diseases", "offsetgroup": "The Lancet Infectious Diseases", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1019388], "xaxis": "x", "y": ["The Lancet Infectio ...

# %% [markdown]
# **Below is a tree representation of the above data**

# %%
fig = aware.treemap(PEOPLE_AWARE, path=['Journals'], values='Number_of_Readers',title='Tree of READERS WHO READ ABOUT COVID-19 in these Journals',width=1200, height=700)
fig.show()
# Out:
# <div>
#
#
#             <div id="025979d8-83b1-4ef7-a01a-b95a4a09f39d" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("025979d8-83b1-4ef7-a01a-b95a4a09f39d")) {
#                     Plotly.newPlot(
#                         '025979d8-83b1-4ef7-a01a-b95a4a09f39d',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Number_of_Readers=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Anaesthesia", "Anesth Analg", "Asian Journal of Psychiatry", "BMJ", "Brain, Behavior, and Immunity", "C&EN Global Enterprise", "Clinical Infectious Diseases", "Critical Care", "European Heart Journal", "Eurosurveillance", "Gastroenterology", "Head & neck", "Infection Control & Hospital Epidemiology", "International Journal of Infectious Diseases", "JAMA", "Journal of Clinical Virology", "Journal of Hospital Infection", "Journal of Infection", "Journal of medical virology", "Journal of the American Academy of Dermatology", "Journal of the American Geriatrics Society", "Medical Hypotheses", "Nature", "New England Journal of Medicine", "New Scientist", "Psychiatry Research", "Radiology", "Revue medicale suisse", "Science", "Science of The Total Environment", "The Lancet", "The Lancet Infectious Diseases", "Travel Medicine and Infectious Disease"], "labels": ["Anaesthesia", "Anesth Analg", "Asian Journal of Psychiatry", "BMJ", "Brain, Behavior, and Immunity", "C&EN Global Enterprise", "Clinical Infectious Diseases", "Critical Care", "European Heart Journal", "Eurosurveillance", "Gastroenterology", "Head & neck", "Infection Control & Hospital Epidemiology", "International Journal of Infectious Diseases", "JAMA", "Journal of Clinical Virology", "Journal of Hospital Infection", "Journal of Infection", "Journal of medical virology", "Journal of the American Academy of Dermatology", "Journal of the American Geriatrics Society", "Medical Hypotheses", "Nature", "New England Journal of Medicine", "New Scientist", "Psychiatry Research", "Radiology", "Revue medicale suisse", "Science", "Science of The Total Environment", "The Lancet", "The Lancet Infectious Diseases", "Travel Medicine and Infectious Disease"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [2400000, 117120, 2000000, 50000000, 150144, 311172, 179928, 300068, 359256, 2800000, 30000, 500000, 496176, 362148, 20000000, 11844, 272268, 176796, 290796, 1942080, 320172, 2906226, 400000, 600000, 1000000, 265268, 54000, 330252, 570400, 286674, 10159512, 1019388, 3000000]}],
#                         {"height": 700, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}] ...

# %% [markdown]
# **THIS WORK IS IN PROGRESS AND I WILL KEEP ON UPDATING THIS KERNEL**
